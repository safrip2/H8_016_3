# %% [markdown]
# # Jupyter Notebook Basic Command

# %% [markdown]
# ## Simple Syntax

# %% [markdown]
# ## Library

# %% [markdown]
# ## Command Shell

# %% [markdown]
# ## Latex

# %%
# %%latex
# $$ (x^5) * \sqrt[4]{5} $$
# Out:
# $$ (x^5) * \sqrt[4]{5} $$
